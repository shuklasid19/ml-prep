# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.linspace(0,5,11)

# %%
y = x**2

# %%
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('x and y')
# Out:
# Text(0.5, 1.0, 'x and y')

# %%
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('x and y')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
plt.subplot(1,3,1)
plt.plot(x,y,'r')

plt.subplot(1,3,2)
plt.plot(y,x,'b')

plt.subplot(1,3,3)
plt.plot(y,x,'b')

# %%
#fig 
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.plot(x,y)
axes.set_xlabel('X label')
axes.set_ylabel('Y label')
axes.set_title('set over title')
# Out:
# Text(0.5, 1.0, 'set over title')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.15, 0.5, 0.3])

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.0, 0.0, 0.2, 0.9])
axes2 = fig.add_axes([0.2, 0.15, 0.4, 0.1])

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

axes1.plot(x, y)
axes1.set_title('LARGER PLOT')

axes2.plot(y, x)
axes.set_title('SMALLER PLOT')
# Out:
# Text(0.5, 1, 'SMALLER PLOT')

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.2,0.6,0.8])
axes.plot(x,y)
axes.set_xlabel('x label')
axes.set_ylabel('y label')
axes.set_title('Set title')
# Out:
# Text(0.5, 1.0, 'Set title')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

#axes.plot(x, y)

# %%
fig, axes = plt.subplots()
axes.plot(x, y)

# %%
fig,axes = plt.subplots(nrows=3, ncols=3)

# %%
fig,axes = plt.subplots(nrows=1, ncols=2)

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000299839796D8>,
# ...
#       dtype=object)

# %%
fig, axes = plt.subplots(1,2)

for current_ax in axes:
    current_ax.plot(x,y)

# %%
axes[0].plot(x,y)
axes[1].plot(y,x)

# %%
fig, axes = plt.subplots(1,2)

axes[0].plot(x ,y)
axes[0].set_title('first plot')

axes[1].plot(y, x)
axes[1].set_title('second plot')
# Out:
# Text(0.5, 1.0, 'second plot')

# %%
fig = plt.figure(figsize=(3,2), dpi=100)
fig.show()
# Out:
# C:\Users\sid\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
fig, axes = plt.figure(figsize=(3,2))
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y)

# %%
fig, axes = plt.subplots(nrows=2 , ncols=1, figsize=(8,2))
axes[0].plot(x, y)
axes[1].plot(y, x)

plt.tight_layout()

# %%
fig.savefig('my_picture.png', dpi=200)

# %%
fig.savefig('my_picture.jpg', dpi=200)

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y)

ax.set_title('Title')
ax.set_ylabel('y label')
ax.set_xlabel('x label')
# Out:
# Text(0.5, 0, 'x label')

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x,x**2, label='x sqaure')
ax.plot(y,x**3, label='x cube')

ax.legend()
ax.legend(loc=0)

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x,x**2, label='x sqaure')
ax.plot(y,x**3, label='x cube')

ax.legend()
ax.legend(loc=(0.2, 0.2))

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y, color='blue')
ax.plot(x, y, color='#FF8C00', linewidth=2) #RGB hex code

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y, color='blue')
ax.plot(x, y, color='#FF8C00', linewidth=200) #RGB hex code

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y, color='blue')
ax.plot(x, y, color='#FF8C00', linewidth=4, alpha=0.5) #RGB hex code

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y, color='blue')

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y, color='#FF8C00', linewidth=4, linestyle='steps')
# Out:
# C:\Users\sid\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).
#   after removing the cwd from sys.path.

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y, color='#FF8C00', linewidth=4, linestyle='-'.marker='')

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y, color='purple', lw=3, linestyle='-',
marker='*', markersize=20)

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y, color='purple', lw=3, linestyle='-',
marker='*', markersize=20,
markerfacecolor='yellow', markeredgewidth=3)

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y, color='purple', lw=3, linestyle='-',
marker='*', markersize=20,
markerfacecolor='green', markeredgewidth=3)

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y, color='purple', lw=3, linestyle='-', markersize=20,
markerfacecolor='green', markeredgewidth=3)
ax.set_xlim([0,1])
ax.set_ylim([0, 2])
# Out:
# (0, 2)

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([10., 11., 14.,  7.,  6., 14., 10.,  4.,  9., 15.]),
#  array([  2., 101., 200., 299., 398., 497., 596., 695., 794., 893., 992.]),
#  <a list of 10 Patch objects>)

# %%
data = [np.radnom.normal(0, std, 100) for std in range(1, 4)]

plt.boxplot(data, vert=True, patch_artist=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-76a6659a2bc6> in <module>
# ----> 1 data = [np.radnom.normal(0, std, 100) for std in range(1, 4)]
#       2
#       3 plt.boxplot(data, vert=True, patch_artist=True)
#
# <ipython-input-78-76a6659a2bc6> in <listcomp>(.0)
# ----> 1 data = [np.radnom.normal(0, std, 100) for std in range(1, 4)]
#       2
#       3 plt.boxplot(data, vert=True, patch_artist=True)
#
# AttributeError: module 'numpy' has no attribute 'radnom'
