# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.0.0-alpha0'

# %% [markdown]
# # generate random input data to train on

# %%
#size of dataset itll generate
observations = 1000
xs = np.random.uniform(low=-10, high=10, size=(observations, 1))
zs = np.random.uniform(low=-10, high=10, size=(observations, 1))
#stack them into 2d 
inputs = np.column_stack((xs, zs))

print(inputs.shape)
# Out:
# (1000, 2)

# %%
inputs
# Out:
# array([[ 0.50719521,  5.30073685],
#        [ 7.61629932, -5.70863118],
#        [ 2.74453517, -2.510963  ],
#        ...,
#        [ 3.31425042, -8.3736953 ],
#        [ 0.26910751, -2.95015491],
#        [ 0.03475424, -4.20224978]])

# %% [markdown]
# create targets we aiming to

# %%
#noise
noise = np.random.uniform(-1, 1, (observations , 1))

targets = 2*xs - 3*zs + 5 * noise

targets.shape
# Out:
# (1000, 1)

# %% [markdown]
# # # the plot trainig data

# %%
targets = targets.reshape(observations, )
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.plot(xs, zs, targets)
ax.set_xlabel('xs')
ax.set_ylabel('zs')
ax.set_zlabel('targets')
ax.view_init(azim=100)
plt.show()
targets = targets.reshape(observations, 1)

# %% [markdown]
# ## initialize variables

# %%
init_range = 0.1
weights = np.random.uniform(-init_range, init_range , size=(2,1))

biases =  np.random.uniform(-init_range, init_range, size= 1)

print(weights)
print(biases)
# Out:
# [[ 0.06662732]
#  [-0.02164649]]
# [-0.05609396]

# %% [markdown]
# # learning rate

# %%
learning_rate = 0.2

# %%
for i in range(200):
    outputs = np.dot(inputs, weights) + biases
    #delta difference btwn real and predicted
    deltas = outputs - targets
    
    loss = np.sum(deltas**2)/2/observations
    print(loss)
    
    deltas_scaled = deltas / observations
    #update weights gradient descent
    weights = weights - learning_rate * np.dot(inputs.T, deltas_scaled) 
    #update the biases
    biases = biases - learning_rate * np.sum(deltas_scaled)
# Out:
# 221.6489671727866
# 7755.448724493125
# 276544.18306897464
# 9876982.99223584
# 353081734.64646447
# 12630790854.8767
# 452090876863.7321
# 16188624099026.324
# 579886363340654.0
# 2.0777479555827664e+16
# 7.446202067999451e+17
# 2.66900295059557e+19
# 9.567975852030722e+20
# 3.4303282359415186e+22
# 1.2299467144975592e+24
# 4.410262099193098e+25
# 1.5814813585881166e+27
# 5.671274732932979e+28
# 2.0338109610565314e+30
# 7.293750592946938e+31
# 2.615769168260518e+33
# 9.381112519754945e+34
# 3.3644518059125654e+36
# 1.2066414258106935e+38
# 4.3275814684508916e+39
# 1.5520821601089384e+41
# 5.566549445833611e+42
# 1.9964522763847305e+44
# 7.160328885216245e+45
# 2.5680763429406413e+47
# 9.210508617114467e+48
# 3.303390107494343e+50
# 1.1847768506710411e+52
# 4.2492629375906555e+53
# 1.5240209073947182e+55
# 5.465985302714001e+56
# 1.9604066317608194e+58
# 7.031111721969181e+59
# 2.5217494712260008e+61
# 9.044404128876066e+62
# 3.2438296913424884e+64
# 1.1634190745842064e+66
# 4.172673027113246e+67
# 1.4965545786050595e+69
# 5.367484384991118e+70
# 1.9250811360825103e+72
# 6.904421591060074e+73
# 2.476313226373284e+75
# 8.881449725851123e+76
# 3.1853866344792084e+78
# 1.1424585463319093e+80
# 4.097498021999406e+81
# 1.4695929430994897e+83
# 5.270785782886275e+84
# 1.8903998577602626e+86
# 6.780035811059836e+87
# 2.4317017137943023e+89
# 8.72144838718947e+90
# 3.128001336717184e+92
# 1.1218770028166766e+94
# 4.0236811798061675e+95
# 1.443118114613267e+97
# 5.175832281768609e+98
# 1.8563442280016775e+100
# 6.657893275395164e+101
# 2.3878945624981096e+103
# 8.564331399256776e+104
# 3.071650377016235e+106
# 1.1016663882249804e+108
# 3.951194576645642e+109
# 1.4171203506765718e+111
# 5.082589706747929e+112
# 1.8229022056187363e+114
# 6.537951404971576e+115
# 2.344876672136463e+117
# 8.410045084634153e+118
# 3.0163146389618977e+120
# 1.0818198844151285e+122
# 3.8800138659798885e+123
# 1.39159094940351e+125
# 4.991026932812475e+126
# 1.79006265130658e+128
# 6.420170315159551e+129
# 2.3026337567430264e+131
# 8.258538259009998e+132
# 2.9619757799514126e+134
# 1.0623309169108158e+136
# 3.810115479894109e+137
# 1.3665214613504584e+139
# 4.901113664893896e+140
# 1.757814702192108e+142
# 6.304511053023172e+143
# 2.2611518476972516e+145
# 8.109760828946332e+146
# 2.908615835319068e+148
# 1.0431930430394745e+150
# 3.7414763126557046e+151
# 1.3419035998724606e+153
# 4.812820183465846e+154
# 1.7261476994755636e+156
# 6.190935390940172e+157
# 2.220417234657403e+159
# 7.963663622105944e+160
# 2.8562171692853486e+162
# 1.0243999376713101e+164
# 3.6740736789407925e+165
# 1.3177292287787093e+167
# 4.726117307691968e+168
# 1.695051177301976e+170
# 6.079405792565867e+171
# 2.1804164550070884e+173
# 7.820198354055175e+174
# 2.8047624643599813e+176
# 1.0059453897871302e+178
# 3.607885302561245e+179
# 1.2939903585811922e+181
# 4.6409763827924864e+182
# 1.6645148584610751e+184
# 5.969885398060591e+185
# 2.141136288739864e+187
# 7.67931761043195e+188
# 2.754234715091274e+190
# 9.878233002772266e+191
# 3.5428893086849894e+193
# 1.2706791437367121e+195
# 4.557369270243347e+196
# 1.63452865089772e+198
# 5.862338011646043e+199
# 2.1025637540164874e+201
# 7.540974831068512e+202
# 2.70461722238758e+204
# 9.700276799092595e+205
# 3.4790642165603304e+207
# 1.2477878800409876e+209
# 4.4752683384399434e+210
# 1.6050826443662153e+212
# 5.75672808961379e+213
# 2.0646861028663133e+215
# 7.405124294580465e+216
# 2.65589358799188e+218
# 9.525526473470242e+219
# 3.4163889324115357e+221
# 1.2253090020810082e+223
# 4.394646453561044e+224
# 1.57616710715391e+226
# 5.65302072857501e+227
# 2.0274908169732648e+229
# 7.2717211032536485e+230
# 2.608047709061545e+232
# 9.353924272065036e+233
# 3.354842742466972e+235
# 1.2032350807345804e+237
# 4.315476970600817e+238
# 1.5477724828648084e+240
# 5.551181653924969e+241
# 1.9909656035385634e+243
# 7.140721168205639e+244
# 2.5610637728464654e+246
# 9.185413481471584e+247
# 3.294405306113319e+249
# 1.1815588207150395e+251
# 4.237733724562838e+252
# 1.5198893872612627e+254
# 5.451177208515431e+255
# 1.9550983912180002e+257
# 7.012081194814445e+258
# 2.514926251462903e+260
# 9.019938409975336e+261
# 3.235056649173012e+263
# 1.1602730581601765e+265
# 4.161391021812583e+266
# 1.492508605162472e+268
# 5.352974341531007e+269
# 1.9198773261324054e+271
# 6.885758668409945e+272
# 2.469619896761716e+274
# 8.857444369147096e+275
# 3.1767771573029784e+277
# 1.1393707582646387e+279
# 4.086423631585973e+280
# 1.4656210873989867e+282
# 5.256540597566279e+283
# 1.8852907679500641e+285
# 6.761711840223118e+286
# 2.425129735288903e+288
# 8.697877655768837e+289
# 3.1195475695122056e+291
# 1.1188450129549808e+293
# 4.012806777650692e+294
# 1.4392179478219854e+296
# 5.1618441058993736e+297
# 1.851327286039636e+299
# 6.639899713588315e+300
# 2.3814410633369975e+302
# 8.541185534085132e+303
# inf
# inf
# inf
# inf
# inf
# C:\Users\sid\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in square

# %%
weights
# Out:
# array([[-3.86955241e+155],
#        [ 9.43805780e+155]])

# %%
biases
# Out:
# array([2.38176293e+153])

# %%
plt.plot(outputs, targets)
plt.xlabel("outpluts")
plt.ylabel("targtet")
plt.show()
